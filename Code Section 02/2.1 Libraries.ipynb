# %%
# python -m spacy download en_core_web_trf
# python -m spacy download en_core_web_sm
# pip install spacy

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\administrator\anaconda3\lib\site-packages (3.9.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: click in c:\users\administrator\anaconda3\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\administrator\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\administrator\anaconda3\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\administrator\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\administrator\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk 
nltk.__version__
# Out:
# '3.9.1'

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.8.8-cp313-cp313-win_amd64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.13-cp313-cp313-win_amd64.whl.metadata (2.2 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.11-cp313-cp313-win_amd64.whl.metadata (8.8 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.10-cp313-cp313-win_amd64.whl.metadata (2.5 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Downloading thinc-8.3.8-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.1-cp313-cp313-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.4.2 (from spacy)
#   Downloading weasel-0.4.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer-slim<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer_slim-0.20.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\administrator\anaconda3\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\administrator\anaconda3\lib\site-packages (from spacy) (2.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\administrator\anaconda3\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\administrator\anaconda3\lib\site-packages (from spacy) (2.10.3)
# Requirement already satisfied: jinja2 in c:\users\administrator\anaconda3\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\administrator\anaconda3\lib\site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator\anaconda3\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\administrator\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\administrator\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\administrator\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrator\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrator\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrator\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrator\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading blis-1.3.0-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in c:\users\administrator\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\administrator\anaconda3\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.1.8)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.4.2->spacy)
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.4.2->spacy)
#   Downloading smart_open-7.4.4-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: wrapt in c:\users\administrator\anaconda3\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\administrator\anaconda3\lib\site-packages (from jinja2->spacy) (3.0.2)
# Downloading spacy-3.8.8-cp313-cp313-win_amd64.whl (14.2 MB)
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.2 MB 1.7 MB/s eta 0:00:09
#    -- ------------------------------------- 0.8/14.2 MB 1.7 MB/s eta 0:00:09
#    -- ------------------------------------- 1.0/14.2 MB 1.7 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.6/14.2 MB 1.7 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.8/14.2 MB 1.7 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.1/14.2 MB 1.7 MB/s eta 0:00:08
#    ------- -------------------------------- 2.6/14.2 MB 1.7 MB/s eta 0:00:07
#    -------- ------------------------------- 2.9/14.2 MB 1.7 MB/s eta 0:00:07
#    -------- ------------------------------- 3.1/14.2 MB 1.7 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.7/14.2 MB 1.7 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.9/14.2 MB 1.7 MB/s eta 0:00:07
#    ------------ --------------------------- 4.5/14.2 MB 1.7 MB/s eta 0:00:06
#    ------------- -------------------------- 4.7/14.2 MB 1.7 MB/s eta 0:00:06
#    -------------- ------------------------- 5.0/14.2 MB 1.7 MB/s eta 0:00:06
#    --------------- ------------------------ 5.5/14.2 MB 1.7 MB/s eta 0:00:06
#    ---------------- ----------------------- 5.8/14.2 MB 1.7 MB/s eta 0:00:06
#    ----------------- ---------------------- 6.0/14.2 MB 1.7 MB/s eta 0:00:05
#    ------------------ --------------------- 6.6/14.2 MB 1.7 MB/s eta 0:00:05
#    ------------------- -------------------- 6.8/14.2 MB 1.7 MB/s eta 0:00:05
#    ------------------- -------------------- 7.1/14.2 MB 1.7 MB/s eta 0:00:05
#    --------------------- ------------------ 7.6/14.2 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.9/14.2 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.1/14.2 MB 1.7 MB/s eta 0:00:04
#    ------------------------ --------------- 8.7/14.2 MB 1.7 MB/s eta 0:00:04
#    ------------------------- -------------- 8.9/14.2 MB 1.7 MB/s eta 0:00:04
#    ------------------------- -------------- 9.2/14.2 MB 1.7 MB/s eta 0:00:04
#    --------------------------- ------------ 9.7/14.2 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.0/14.2 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.2/14.2 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 10.7/14.2 MB 1.7 MB/s eta 0:00:03
#    ------------------------------- -------- 11.0/14.2 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 11.5/14.2 MB 1.7 MB/s eta 0:00:02
#    --------------------------------- ------ 11.8/14.2 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 12.1/14.2 MB 1.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 12.6/14.2 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 12.8/14.2 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 13.1/14.2 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 13.6/14.2 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  13.9/14.2 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 14.2/14.2 MB 1.6 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.11-cp313-cp313-win_amd64.whl (39 kB)
# Downloading murmurhash-1.0.13-cp313-cp313-win_amd64.whl (24 kB)
# Downloading preshed-3.0.10-cp313-cp313-win_amd64.whl (115 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.1-cp313-cp313-win_amd64.whl (630 kB)
#    ---------------------------------------- 0.0/630.6 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/630.6 kB ? eta -:--:--
#    ---------------------------------------- 630.6/630.6 kB 1.5 MB/s eta 0:00:00
# Downloading thinc-8.3.8-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 1.7 MB/s eta 0:00:01
#    ------------------------ --------------- 1.0/1.7 MB 1.7 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 1.6 MB/s eta 0:00:00
# Downloading blis-1.3.0-cp313-cp313-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.3 MB 1.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 0.8/6.3 MB 1.7 MB/s eta 0:00:04
#    -------- ------------------------------- 1.3/6.3 MB 1.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.6/6.3 MB 1.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.8/6.3 MB 1.7 MB/s eta 0:00:03
#    --------------- ------------------------ 2.4/6.3 MB 1.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 2.6/6.3 MB 1.7 MB/s eta 0:00:03
#    ------------------ --------------------- 2.9/6.3 MB 1.7 MB/s eta 0:00:03
#    --------------------- ------------------ 3.4/6.3 MB 1.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.7/6.3 MB 1.7 MB/s eta 0:00:02
#    ------------------------- -------------- 3.9/6.3 MB 1.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.5/6.3 MB 1.7 MB/s eta 0:00:02
#    ------------------------------ --------- 4.7/6.3 MB 1.7 MB/s eta 0:00:01
#    ------------------------------- -------- 5.0/6.3 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.3 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 5.8/6.3 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 1.6 MB/s eta 0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading typer_slim-0.20.0-py3-none-any.whl (47 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.2-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Downloading smart_open-7.4.4-py3-none-any.whl (63 kB)
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, smart-open, murmurhash, cloudpathlib, catalogue, blis, typer-slim, srsly, preshed, confection, weasel, thinc, spacy
#
#    ----- ----------------------------------  2/16 [spacy-loggers]
#    ------- --------------------------------  3/16 [spacy-legacy]
#    ---------- -----------------------------  4/16 [smart-open]
#    --------------- ------------------------  6/16 [cloudpathlib]
#    --------------- ------------------------  6/16 [cloudpathlib]
#    --------------- ------------------------  6/16 [cloudpathlib]
#    -------------------- -------------------  8/16 [blis]
#    -------------------- -------------------  8/16 [blis]
#    -------------------- -------------------  8/16 [blis]
#    ---------------------- -----------------  9/16 [typer-slim]
#    ---------------------- -----------------  9/16 [typer-slim]
#    ------------------------- -------------- 10/16 [srsly]
#    ------------------------- -------------- 10/16 [srsly]
#    ------------------------- -------------- 10/16 [srsly]
#    ------------------------- -------------- 10/16 [srsly]
#    ------------------------- -------------- 10/16 [srsly]
#    ------------------------- -------------- 10/16 [srsly]
#    ------------------------- -------------- 10/16 [srsly]
#    ------------------------- -------------- 10/16 [srsly]
#    ------------------------- -------------- 10/16 [srsly]
#    ------------------------- -------------- 10/16 [srsly]
#    ------------------------------ --------- 12/16 [confection]
#    ------------------------------ --------- 12/16 [confection]
#    -------------------------------- ------- 13/16 [weasel]
#    -------------------------------- ------- 13/16 [weasel]
#    ----------------------------------- ---- 14/16 [thinc]
#    ----------------------------------- ---- 14/16 [thinc]
#    ----------------------------------- ---- 14/16 [thinc]
#    ----------------------------------- ---- 14/16 [thinc]
#    ----------------------------------- ---- 14/16 [thinc]
#    ----------------------------------- ---- 14/16 [thinc]
#    ----------------------------------- ---- 14/16 [thinc]
#    ----------------------------------- ---- 14/16 [thinc]
#    ----------------------------------- ---- 14/16 [thinc]
#    ----------------------------------- ---- 14/16 [thinc]
#    ----------------------------------- ---- 14/16 [thinc]
#    ----------------------------------- ---- 14/16 [thinc]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ---------------------------------------- 16/16 [spacy]
#
# Successfully installed blis-1.3.0 catalogue-2.0.10 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.11 murmurhash-1.0.13 preshed-3.0.10 smart-open-7.4.4 spacy-3.8.8 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.1 thinc-8.3.8 typer-slim-0.20.0 wasabi-1.1.3 weasel-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy 
spacy.__version__
# Out:
# '3.8.8'

# %%
# in anaconda propmt

# python -m spacy download en_core_web_sm
# or
# python -m spacy download en_core_web_lg

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
type(nlp)
# Out:
# spacy.lang.en.English

# %%
import re
